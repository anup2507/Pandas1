# %%
import pandas as pd
import numpy as np

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(data=my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
my_list = [10,20,30]
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(index=labels,data=arr)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
d = {'a':10,'b':20,'c':30}
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
a = pd.Series(data=[1,2,3],index=[20,20,40])

# %%
a
# Out:
# 20    1
# 20    2
# 40    3
# dtype: int64

# %%
labels = ['a','b','c']
pd.Series(data=labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
ser1 = pd.Series([1,2,3,4],index= ['USA','Germany','Italy','Japan'])

# %%
ser1
# Out:
# USA        1
# Germany    2
# Italy      3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,3,4],index = ['USA','Germany','Italy','Japan'])

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      3
# Japan      4
# dtype: int64

# %%
ser2['Italy']
# Out:
# 3

# %%
ser1+ser2
# Out:
# USA        2
# Germany    4
# Italy      6
# Japan      8
# dtype: int64

# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn
np.random.seed(100)

# %%
df = pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A -0.164025  1.216581 -0.626854 -0.274940
# B  1.147457  1.159969  0.702185 -1.283905
# C  1.522308 -0.179963 -0.376147  0.460349
# D  1.455421  0.241507 -0.037667  0.831533
# E  2.299369 -0.939602  0.111823  2.539432

# %%
df['W']
# Out:
# A   -0.164025
# B    1.147457
# C    1.522308
# D    1.455421
# E    2.299369
# Name: W, dtype: float64

# %%
df['X']
# Out:
# A    1.216581
# B    1.159969
# C   -0.179963
# D    0.241507
# E   -0.939602
# Name: X, dtype: float64

# %%
df['Z']
# Out:
# A   -0.274940
# B   -1.283905
# C    0.460349
# D    0.831533
# E    2.539432
# Name: Z, dtype: float64

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# B  1.147457  1.159969  0.702185 -1.283905
# C  1.522308 -0.179963 -0.376147  0.460349
# D  1.455421  0.241507 -0.037667  0.831533
# E  2.299369 -0.939602  0.111823  2.539432

# %%
df[df['X']>1]
# Out:
#           W         X         Y         Z
# A -0.164025  1.216581 -0.626854 -0.274940
# B  1.147457  1.159969  0.702185 -1.283905

# %%
df[df['Z']>0]
# Out:
#           W         X         Y         Z
# C  1.522308 -0.179963 -0.376147  0.460349
# D  1.455421  0.241507 -0.037667  0.831533
# E  2.299369 -0.939602  0.111823  2.539432

# %%
df[['W','Z']]
# Out:
#           W         Z
# A -0.164025 -0.274940
# B  1.147457 -1.283905
# C  1.522308  0.460349
# D  1.455421  0.831533
# E  2.299369  2.539432

# %%
df[['W','Z']]
# Out:
#           W         Z
# A -0.164025 -0.274940
# B  1.147457 -1.283905
# C  1.522308  0.460349
# D  1.455421  0.831533
# E  2.299369  2.539432

# %%
df.W
# Out:
# A   -0.164025
# B    1.147457
# C    1.522308
# D    1.455421
# E    2.299369
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
df
# Out:
#           W         X         Y         Z
# A -0.164025  1.216581 -0.626854 -0.274940
# B  1.147457  1.159969  0.702185 -1.283905
# C  1.522308 -0.179963 -0.376147  0.460349
# D  1.455421  0.241507 -0.037667  0.831533
# E  2.299369 -0.939602  0.111823  2.539432

# %% [markdown]
# Creating a new column

# %%
df['new'] = df['W'] + df['Y']

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.164025  1.216581 -0.626854 -0.274940 -0.790879
# B  1.147457  1.159969  0.702185 -1.283905  1.849642
# C  1.522308 -0.179963 -0.376147  0.460349  1.146160
# D  1.455421  0.241507 -0.037667  0.831533  1.417755
# E  2.299369 -0.939602  0.111823  2.539432  2.411192

# %% [markdown]
# Removing Columns

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A -0.164025  1.216581 -0.626854 -0.274940
# B  1.147457  1.159969  0.702185 -1.283905
# C  1.522308 -0.179963 -0.376147  0.460349
# D  1.455421  0.241507 -0.037667  0.831533
# E  2.299369 -0.939602  0.111823  2.539432

# %%
df
# Out:
#           W         X         Y         Z       new
# A -0.164025  1.216581 -0.626854 -0.274940 -0.790879
# B  1.147457  1.159969  0.702185 -1.283905  1.849642
# C  1.522308 -0.179963 -0.376147  0.460349  1.146160
# D  1.455421  0.241507 -0.037667  0.831533  1.417755
# E  2.299369 -0.939602  0.111823  2.539432  2.411192

# %%
df.drop('new',axis=1,inplace=True)

# %%
df
# Out:
#           W         X         Y         Z
# A -0.164025  1.216581 -0.626854 -0.274940
# B  1.147457  1.159969  0.702185 -1.283905
# C  1.522308 -0.179963 -0.376147  0.460349
# D  1.455421  0.241507 -0.037667  0.831533
# E  2.299369 -0.939602  0.111823  2.539432

# %%
df.drop('E')
# Out:
#           W         X         Y         Z
# A -0.164025  1.216581 -0.626854 -0.274940
# B  1.147457  1.159969  0.702185 -1.283905
# C  1.522308 -0.179963 -0.376147  0.460349
# D  1.455421  0.241507 -0.037667  0.831533

# %%
df
# Out:
#           W         X         Y         Z
# A -0.164025  1.216581 -0.626854 -0.274940
# B  1.147457  1.159969  0.702185 -1.283905
# C  1.522308 -0.179963 -0.376147  0.460349
# D  1.455421  0.241507 -0.037667  0.831533
# E  2.299369 -0.939602  0.111823  2.539432

# %%
df.loc['A']
# Out:
# W   -0.164025
# X    1.216581
# Y   -0.626854
# Z   -0.274940
# Name: A, dtype: float64

# %%
df.iloc[2]
# Out:
# W    1.522308
# X   -0.179963
# Y   -0.376147
# Z    0.460349
# Name: C, dtype: float64

# %%
df.loc['B','Y']
# Out:
# 0.702184505359777

# %%
df.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A -0.164025 -0.626854
# B  1.147457  0.702185

# %%
df
# Out:
#           W         X         Y         Z
# A -0.164025  1.216581 -0.626854 -0.274940
# B  1.147457  1.159969  0.702185 -1.283905
# C  1.522308 -0.179963 -0.376147  0.460349
# D  1.455421  0.241507 -0.037667  0.831533
# E  2.299369 -0.939602  0.111823  2.539432

# %%
df>0
# Out:
#        W      X      Y      Z
# A  False   True  False  False
# B   True   True   True  False
# C   True  False  False   True
# D   True   True  False   True
# E   True  False   True   True

# %%
df[df>0]
# Out:
#           W         X         Y         Z
# A       NaN  1.216581       NaN       NaN
# B  1.147457  1.159969  0.702185       NaN
# C  1.522308       NaN       NaN  0.460349
# D  1.455421  0.241507       NaN  0.831533
# E  2.299369       NaN  0.111823  2.539432

# %%
df['W']>0
# Out:
# A    False
# B     True
# C     True
# D     True
# E     True
# Name: W, dtype: bool

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# B  1.147457  1.159969  0.702185 -1.283905
# C  1.522308 -0.179963 -0.376147  0.460349
# D  1.455421  0.241507 -0.037667  0.831533
# E  2.299369 -0.939602  0.111823  2.539432

# %%
df[df['W']>0]
# Out:
#           W         X         Y         Z
# B  1.147457  1.159969  0.702185 -1.283905
# C  1.522308 -0.179963 -0.376147  0.460349
# D  1.455421  0.241507 -0.037667  0.831533
# E  2.299369 -0.939602  0.111823  2.539432

# %%
df[df['W']>0]['Y']
# Out:
# B    0.702185
# C   -0.376147
# D   -0.037667
# E    0.111823
# Name: Y, dtype: float64

# %%
df['Y']>1
# Out:
# A    False
# B    False
# C    False
# D    False
# E    False
# Name: Y, dtype: bool

# %%
df['W']>0
# Out:
# A    False
# B     True
# C     True
# D     True
# E     True
# Name: W, dtype: bool

# %%
df[(df['W']>0) & (df['Y']>1)]
# Out:
# Empty DataFrame
# Columns: [W, X, Y, Z]
# Index: []

# %%
df
# Out:
#           W         X         Y         Z
# A -0.164025  1.216581 -0.626854 -0.274940
# B  1.147457  1.159969  0.702185 -1.283905
# C  1.522308 -0.179963 -0.376147  0.460349
# D  1.455421  0.241507 -0.037667  0.831533
# E  2.299369 -0.939602  0.111823  2.539432

# %%
df.reset_index()
# Out:
#   index         W         X         Y         Z
# 0     A -0.164025  1.216581 -0.626854 -0.274940
# 1     B  1.147457  1.159969  0.702185 -1.283905
# 2     C  1.522308 -0.179963 -0.376147  0.460349
# 3     D  1.455421  0.241507 -0.037667  0.831533
# 4     E  2.299369 -0.939602  0.111823  2.539432

# %%
'CA NY WY OR CO'.split()
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
newind = 'CA NY WY OR CO'.split()

# %%
df['States'] = newind

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.164025  1.216581 -0.626854 -0.274940     CA
# B  1.147457  1.159969  0.702185 -1.283905     NY
# C  1.522308 -0.179963 -0.376147  0.460349     WY
# D  1.455421  0.241507 -0.037667  0.831533     OR
# E  2.299369 -0.939602  0.111823  2.539432     CO

# %%
df.set_index('States')
# Out:
#                W         X         Y         Z
# States
# CA     -0.164025  1.216581 -0.626854 -0.274940
# NY      1.147457  1.159969  0.702185 -1.283905
# WY      1.522308 -0.179963 -0.376147  0.460349
# OR      1.455421  0.241507 -0.037667  0.831533
# CO      2.299369 -0.939602  0.111823  2.539432

# %%
df
# Out:
#           W         X         Y         Z States
# A -0.164025  1.216581 -0.626854 -0.274940     CA
# B  1.147457  1.159969  0.702185 -1.283905     NY
# C  1.522308 -0.179963 -0.376147  0.460349     WY
# D  1.455421  0.241507 -0.037667  0.831533     OR
# E  2.299369 -0.939602  0.111823  2.539432     CO

# %%
df.set_index('States',inplace=True)

# %%
df
# Out:
#                W         X         Y         Z
# States
# CA     -0.164025  1.216581 -0.626854 -0.274940
# NY      1.147457  1.159969  0.702185 -1.283905
# WY      1.522308 -0.179963 -0.376147  0.460349
# OR      1.455421  0.241507 -0.037667  0.831533
# CO      2.299369 -0.939602  0.111823  2.539432

# %%
df = pd.DataFrame(data={'A':[1,2,np.nan],
                  'B':[5,np.nan,np.nan],
                  'C':[1,2,3]})

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna(thresh=1)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value='FILL VALUE')
# Out:
#             A           B  C
# 0           1           5  1
# 1           2  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df['A'].fillna(value='+""')
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df['A'].mean()
# Out:
# 1.5

# %%
df['A'] = df['A'].fillna(value=df['A'].mean())

# %%
df['A']
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
df['B'] = df['B'].fillna(value=df['B'].mean())

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  1.5  5.0  3
